# %% [markdown]
# ## Terraforming Mars Cost-Benefit Analysis
# <br>
# Terraforming Mars is a competitive board game developed by Jacob Fryxelius and published by FryxGames in 2016. Players take on the role of corporations tasked with making Mars habitable through the raising of the oxygen level, temperature, and ocean coverage, as well as sundry other projects to progress humanity.
#
# Currently sitting at #4 on BoardGameGeek's ranked board game list, Terraforming Mars has found broad popularity among strategy board gamers in large part due to its variety and complexity. With 208 unique cards and 12 distinct corporations, players are put into an endless assortment of scenarios. This incredible depth means that players must often intuit their next move rather than deduce it from values and probabilities.
#
# In a bid to add more deduction back into the equation, this analysis aims to take every card in Terraforming Mars and boil it down to a single value in credits (the game's main resource) for simple value-comparison.
#
# Let's get started.

# %%
import numpy as np
from statistics import median
import pandas as pd
import seaborn as sns
import csv
import ast
import math
from ipynb.fs.defs.TM_lib import vars_scan, pers, ors

np.set_printoptions(threshold=np.inf)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# The base_cards database, populated from a hand-entered csv, follows a couple of conventions:
# * When a resource is written in uppercase it refers to that resource's production, whereas when written in lowercase it refers to the resource iself.
# * All nouns are written in the singular in order to simplify pandas referencing.
#
# The all_games database is a collection of stats from over 12,000 individually logged games downloaded from Simeon Simeonov's excellent [Terraforming Mars website](https://ssimeonoff.github.io/). The base_games database contains only the matches from all_games which were played with the full base version of the game.

# %%
# create databases
base_cards = pd.read_csv('TM_base_project_list.csv')
all_games = pd.read_csv('games_list.csv')
base_games = all_games[(all_games.expansions == "['CORPORATE']") & (all_games.map == "THARSIS")]

# %% [markdown]
# First, an average number of generations for each player count must be derived from base_games. These will be used to determine the income which will be generated over the remainder of the game for a given card after the generation during which it is played. They'll also be used to split the game into four quarters to illustrate how a card's value changes over time.

# %%
# determine generation averages per player count
last_gen_2p = int(round(base_games[base_games.players == 2].generations.mean()))
last_gen_3p = int(round(base_games[base_games.players == 3].generations.mean()))
last_gen_4p = int(round(base_games[base_games.players == 4].generations.mean()))
last_gen_5p = int(round(base_games[base_games.players == 5].generations.mean()))

last_gens = {
            'last_gen_2p': int(round(base_games[base_games.players == 2].generations.mean())),
            'last_gen_3p': int(round(base_games[base_games.players == 3].generations.mean())),
            'last_gen_4p': int(round(base_games[base_games.players == 4].generations.mean())),
            'last_gen_5p': int(round(base_games[base_games.players == 5].generations.mean()))
           }

print(f'''
Average length of game in generations:
2p: {last_gen_2p}
3p: {last_gen_3p}
4p: {last_gen_4p}
5p: {last_gen_5p}
''')

# average game length split into quarters with the median generation taken from each quarter
# X players, quarter N, median generation
gen_quarters = {
               '2p_q1_gen':round(last_gen_2p/4/2),
               '2p_q2_gen':round(last_gen_2p/4/2 + last_gen_2p/4),
               '2p_q3_gen':round(last_gen_2p/4/2 + last_gen_2p/4*2),
               '2p_q4_gen':round(last_gen_2p/4/2 + last_gen_2p/4*3),
               '3p_q1_gen':round(last_gen_3p/4/2),
               '3p_q2_gen':round(last_gen_3p/4/2 + last_gen_3p/4),
               '3p_q3_gen':round(last_gen_3p/4/2 + last_gen_3p/4*2),
               '3p_q4_gen':round(last_gen_3p/4/2 + last_gen_3p/4*3),
               '4p_q1_gen':round(last_gen_4p/4/2),
               '4p_q2_gen':round(last_gen_4p/4/2 + last_gen_4p/4),
               '4p_q3_gen':round(last_gen_4p/4/2 + last_gen_4p/4*2),
               '4p_q4_gen':round(last_gen_4p/4/2 + last_gen_4p/4*3),
               '5p_q1_gen':round(last_gen_5p/4/2),
               '5p_q2_gen':round(last_gen_5p/4/2 + last_gen_5p/4),
               '5p_q3_gen':round(last_gen_5p/4/2 + last_gen_5p/4*2),
               '5p_q4_gen':round(last_gen_5p/4/2 + last_gen_5p/4*3)
              }
keys_2p_gen = ['2p_q1_gen', '2p_q2_gen', '2p_q3_gen', '2p_q4_gen']
keys_3p_gen = ['3p_q1_gen', '3p_q2_gen', '3p_q3_gen', '3p_q4_gen']
keys_4p_gen = ['4p_q1_gen', '4p_q2_gen', '4p_q3_gen', '4p_q4_gen']
keys_5p_gen = ['5p_q1_gen', '5p_q2_gen', '5p_q3_gen', '5p_q4_gen']

print(f'''
Generation quarters:
2p: {str([gen_quarters.get(key) for key in keys_2p_gen]).strip('[]')}
3p: {str([gen_quarters.get(key) for key in keys_3p_gen]).strip('[]')}
4p: {str([gen_quarters.get(key) for key in keys_4p_gen]).strip('[]')}
5p: {str([gen_quarters.get(key) for key in keys_5p_gen]).strip('[]')}
''')
# Out:
# Average length of game in generations:
# 2p: 13
# 3p: 11
# 4p: 10
# 5p: 10
#
#
# Generation quarters:
# 2p: 2, 5, 8, 11
# 3p: 1, 4, 7, 10
# 4p: 1, 4, 6, 9
# 5p: 1, 4, 6, 9

# %% [markdown]
# Next, each resource in the game must be converted to a number of credits. The [standard projects](https://3.bp.blogspot.com/-fs7vQZGRFs4/XAjAYOSBspI/AAAAAAAAFSA/kInbyuaLoLc0PANwJeFDpJditT5Ims3_wCLcBGAs/s1600/terraforming-mars-standard-projects-1.jpg) are set as listed on the game board, and steel and titanium as listed on the [player boards](https://cf.geekdo-images.com/medium/img/qa7YwBE6pc-ZR0relFRrzUAlQXw=/fit-in/500x500/filters:no_upscale()/pic2891980.jpg).
#
# Plants and heat are set by dividing 8, the number of plants/heat needed to equal a temp/greenery (also illustrated on the player boards), into the credit values for the temp and greenery standard projects.
#
# For energy, it was necessary to borrow some information from one of the expansions: _Colonies_. In order to trade with a colony, players must spend either 9 credits, 3 titanium, or 3 energy. This suggests that 1 energy = 1 titanium = 3 credits.
#
# Drawing a card is valued at 4 credits, combining the price to buy a card (3 credits) with the 1 credit gained from discarding it using the "Sell patents" standard project.

# %%
# variable definitions

income = 0
vp = 0
TR = vp + income

# standard projects
temp = 14
ocean = 18
greenery = 23
def city(income):
    return 25 - (income + 1)
oxygen = TR

# resources
credit = 1
steel = 2
titanium = 3
plant = greenery / 8
heat = temp / 8
energy = 3
draw = 4

# production
def CREDIT(income):
    return income + 1
def STEEL(income):
    return 2 * income
def TITANIUM(income):
    return 3 * income
def PLANT(income):
    return greenery/8 * (income + 1)
def ENERGY(income):
    return 3 * income
def HEAT(income):
    return (temp/8) * income

vars_dict_static = {'temp':temp, 'ocean':ocean, 'greenery':greenery, 'credit':credit, 'steel':steel, 
                    'titanium':titanium, 'plant':plant, 'heat':heat, 'energy':energy, 'draw':draw}

vars_dict_variable = {'city':city, 'CREDIT':CREDIT, 'STEEL':STEEL, 'TITANIUM':TITANIUM, 
                      'PLANT':PLANT, 'ENERGY':ENERGY, 'HEAT':HEAT}

vars_dict_resource = {}

# %%
# determine number of remaining generations
def remgen(generation, player_count):
    global income
    for players in last_gens:
        if str(player_count) in players:
            last_gen = last_gens[players]
    income = last_gen - generation
    return income, last_gen

# %% [markdown]
# #### Tile placement
#
# Placing a tile on an area with resources allows the player to take those resources, adding to the value of the tile. To determine the average value added from these map resources, the total sum of credits gained from all of the resources on the map are divided by the total number of areas. This is done separately for ocean areas and non-ocean areas. The two off-world areas and the Noctis City area have been disregarded, since they cannot be placed upon except for unique circumstances.
#
# <img src="https://4.bp.blogspot.com/-KVleOqhdyg0/XBxty1rpALI/AAAAAAAAFac/iJsDNEW0SDw6gTK2aHIS0oLc9px5XvzjQCEwYBhgL/s1600/TM%2BOriginal-Mars%2BOnly.jpg" alt="TM map" width="500"/>

# %%
#determine added value from gained resources when placing a tile

tile_land = (
            (2*steel * 3 +
            draw * 3 +
            steel * 3 +
            plant + titanium +
            plant * 10 +
            2*plant * 7 +
            titanium)
            / 48)

tile_ocean = (
             (2*steel +
             draw +
             plant * 3 +
             2*plant * 4 +
             2*titanium)
             / 12)

print(f'Placing a land tile is worth {str(round(tile_land, 3))} credits.')
print(f'Placing an ocean tile is worth {str(round(tile_ocean, 3))} credits.')
# Out:
# Placing a land tile is worth 2.247 credits.
# Placing an ocean tile is worth 3.802 credits.

# %% [markdown]
# Victory points (VP) must also be converted to credits. To do this, the three terraforming standard projects were used. Since they confer a terraforming rating (TR) and not a victory point, the extra income from the TR must be subtracted from the cost of the project. This means that similar to the cards themselves, the value of a VP changes over time.
#
# In addition to the generated income, the average bonus credits accrued through tile placement are also factored into the Aquifer and Greenery standard projects when calculating for VP value.
#
# To come to a single value for a given generation and player count, the "points per credit" are determined for each of the three standard terraforming projects and then the average is taken. Note that greeneries are worth two points (one for the TR from raising the oxygen, another from the greenery tile itself) and so are calculated accordingly.

# %%
# define credits per victory point
def credits_per_vp(generation, player_count):
    income, last_gen = remgen(generation, player_count)
    temp_ppc = 1/(temp - income) # ppc = points per credit
    ocean_ppc = 1/(ocean - income - tile_ocean)
    greenery_ppc = 2/(greenery - income - tile_land)
    ppc = (temp_ppc + ocean_ppc + greenery_ppc)/4
    vp = 1/ppc
    return vp

# numbers of credits per victory point for each player count and median generation
# X players, quarter N, credits per point
gen_credits_per_vp = {'2pq1cpp':credits_per_vp(2, 2),
                      '2pq2cpp':credits_per_vp(5, 2),
                      '2pq3cpp':credits_per_vp(8, 2),
                      '2pq4cpp':credits_per_vp(11, 2),
                      '3pq1cpp':credits_per_vp(1, 3),
                      '3pq2cpp':credits_per_vp(4, 3),
                      '3pq3cpp':credits_per_vp(7, 3),
                      '3pq4cpp':credits_per_vp(10, 3),
                      '4pq1cpp':credits_per_vp(1, 4),
                      '4pq2cpp':credits_per_vp(4, 4),
                      '4pq3cpp':credits_per_vp(6, 4),
                      '4pq4cpp':credits_per_vp(9, 4),
                      '5pq1cpp':credits_per_vp(1, 5),
                      '5pq2cpp':credits_per_vp(4, 5),
                      '5pq3cpp':credits_per_vp(6, 5),
                      '5pq4cpp':credits_per_vp(9, 5)
                     }

keys2pcpp = ['2pq1cpp', '2pq2cpp', '2pq3cpp', '2pq4cpp']
keys3pcpp = ['3pq1cpp', '3pq2cpp', '3pq3cpp', '3pq4cpp']
keys4pcpp = ['4pq1cpp', '4pq2cpp', '4pq3cpp', '4pq4cpp']
keys5pcpp = ['5pq1cpp', '5pq2cpp', '5pq3cpp', '5pq4cpp']

print(f'''
Generation credits per point per quarter:
   q1, q2, q3, q4
2p: {str([round(gen_credits_per_vp.get(key)) for key in keys2pcpp]).strip('[]')}
3p: {str([round(gen_credits_per_vp.get(key)) for key in keys3pcpp]).strip('[]')}
4p: {str([round(gen_credits_per_vp.get(key)) for key in keys4pcpp]).strip('[]')}
5p: {str([round(gen_credits_per_vp.get(key)) for key in keys5pcpp]).strip('[]')}
''')
# Out:
# Generation credits per point per quarter:
#    q1, q2, q3, q4
# 2p: 5, 8, 12, 15
# 3p: 6, 9, 13, 16
# 4p: 7, 10, 13, 16
# 5p: 7, 10, 13, 16

# %%
#run above functions and determine credits per TR
def initialize(generation, player_count):
    income, last_gen = remgen(generation, player_count)
    vp = credits_per_vp(generation, player_count)
    TR = vp + income
    return income, vp, TR, last_gen

# %%
# chance to draw each tag

# Earth
earth_tags = base_cards[base_cards.Tags.str.contains('earth', na=False)]
chance_earth_played = len(earth_tags) / len(base_cards)
chance_earth_showing = len(earth_tags[~earth_tags.Tags.str.contains('event', na=False)]) \
                       / len(base_cards)
# Science
science_tags = base_cards[base_cards.Tags.str.contains('science', na=False)]
chance_science_played = len(science_tags) / len(base_cards)
chance_science_showing = len(science_tags[~science_tags.Tags.str.contains('event', na=False)]) \
                       / len(base_cards)
# Plant
plant_tags = base_cards[base_cards.Tags.str.contains('plant', na=False)]
chance_plant_played = len(plant_tags) / len(base_cards)
chance_plant_showing = len(plant_tags[~plant_tags.Tags.str.contains('event', na=False)]) \
                       / len(base_cards)
# Microbe
microbe_tags = base_cards[base_cards.Tags.str.contains('microbe', na=False)]
chance_microbe_played = len(microbe_tags) / len(base_cards)
chance_microbe_showing = len(microbe_tags[~microbe_tags.Tags.str.contains('event', na=False)]) \
                       / len(base_cards)
# Animal
animal_tags = base_cards[base_cards.Tags.str.contains('animal', na=False)]
chance_animal_played = len(animal_tags) / len(base_cards)
chance_animal_showing = len(animal_tags[~animal_tags.Tags.str.contains('event', na=False)]) \
                       / len(base_cards)
# Space
space_tags = base_cards[base_cards.Tags.str.contains('space', na=False)]
chance_space_played = len(space_tags) / len(base_cards)
chance_space_showing = len(space_tags[~space_tags.Tags.str.contains('event', na=False)]) \
                       / len(base_cards)
# Event
event_tags = base_cards[base_cards.Tags.str.contains('event', na=False)]
chance_event_played = len(event_tags) / len(base_cards)

# Building
building_tags = base_cards[base_cards.Tags.str.contains('building', na=False)]
chance_building_played = len(building_tags) / len(base_cards)
chance_building_showing = len(building_tags[~building_tags.Tags.str.contains('event', na=False)]) \
                       / len(base_cards)
# Jovian
jovian_tags = base_cards[base_cards.Tags.str.contains('jovian', na=False)]
chance_jovian_played = len(jovian_tags) / len(base_cards)
chance_jovian_showing = len(jovian_tags[~jovian_tags.Tags.str.contains('event', na=False)]) \
                       / len(base_cards)
# Power
power_tags = base_cards[base_cards.Tags.str.contains('power', na=False)]
chance_power_played = len(power_tags) / len(base_cards)
chance_power_showing = len(power_tags[~power_tags.Tags.str.contains('event', na=False)]) \
                       / len(base_cards)
# City
city_tags = base_cards[base_cards.Tags.str.contains('city', na=False)]
chance_city_played = len(city_tags) / len(base_cards)
chance_city_showing = len(city_tags[~city_tags.Tags.str.contains('event', na=False)]) \
                       / len(base_cards)

tags_played_dict = {'earth':chance_earth_played, 'science':chance_science_played, 
                    'plant':chance_plant_played, 'microbe':chance_microbe_played, 
                    'animal':chance_animal_played, 'space':chance_space_played,
                    'event':chance_event_played, 'building':chance_building_played, 
                    'jovian':chance_jovian_played,'power':chance_power_played, 
                    'city':chance_city_played}

tags_showing_dict = {'earth':chance_earth_showing, 'science':chance_science_showing, 
                    'plant':chance_plant_showing, 'microbe':chance_microbe_showing, 
                    'animal':chance_animal_showing, 'space':chance_space_showing,
                    'event':chance_event_played, 'building':chance_building_showing, 
                    'jovian':chance_jovian_showing,'power':chance_power_showing, 
                     'city':chance_city_showing}

def cards_current(generation):
    return 10 + (4 * (generation - 1))

# %% [markdown]
# #### Microbes
# The following cards are taken into account when calculating the value of a microbe:
# * Ants - 1 vp per 2 microbes
# * Decomposers - 1 vp per 3 microbes
# * GHG Producing Bacteria - 1 temp per 2 microbes
# * Nitrite Reducing Bacteria - 1 TR per 3 microbes
# * Regolith Eaters - 1 oxygen per 2 microbes
# * Tardigrades - 1 vp per 4 microbes

# %%
# microbe value
# microbe_tags = base_cards[base_cards.Tags.str.contains('microbe', na=False)]
# display(microbe_tags)

def microbe_val(generation, player_count):
    income, vp, TR, last_gen = initialize(generation, player_count)
    
    ants = vp / 2
    decomposers = vp / 3
    ghg_producing_bacteria = temp / 2
    nitrite_reducing_bacteria = TR / 3
    regolith_eaters = greenery / 4
    tardigrades = vp / 4
    
    microbes_list = [ants, decomposers, ghg_producing_bacteria, nitrite_reducing_bacteria,
                     regolith_eaters, tardigrades]
    microbe = sum(microbes_list) / len(microbes_list)
    return microbe

vars_dict_resource.update({'microbe':microbe_val})

print(f'A microbe is worth {str(round(microbe_val(1, 2), 3))} credits in generation 1 with 2 players.')
# Out:
# A microbe is worth 3.59 credits in generation 1 with 2 players.

# %% [markdown]
# #### Animals
#
# The following cards are taken into account when calculating the value of an animal:
# * Birds - 1 vp per animal
# * Fish - 1 vp per animal
# * Livestock - 1 vp per animal
# * Predators - 1 vp per animal
# * Ecological Zone - 1 vp per 2 animals
# * Herbivores - 1 vp per 2 animals
# * Pets - 1 vp per 2 animals
# * Small Animals - 1 vp per 2 animals

# %%
# animal value
# animal_tags = base_cards[base_cards.Tags.str.contains('animal', na=False)]
# display(animal_tags)

def animal_val(generation, player_count):
    income, vp, TR, last_gen = initialize(generation, player_count)
    
    birds= fish= livestock= predators = vp
    ecological_zone= herbivores= pets= small_animals = vp/2
    
    animals_list = [birds, fish, livestock, predators, ecological_zone,
                    herbivores, pets, small_animals]
    animal = sum(animals_list) / len(animals_list)
    return animal

vars_dict_resource.update({'animal':animal_val})

print(f'An animal is worth {str(round(animal_val(1, 2), 3))} credits in generation 1 with 2 players.')
# Out:
# An animal is worth 2.535 credits in generation 1 with 2 players.

# %% [markdown]
# This brings me to the point of actually calculating the card values. My plan is to write a main function for doing this, then running it for most of the cards to create a values database.
#
# Beyond that I've set aside fifteen active cards that have a cost to use. Ironworks, for example, costs 4 energy to use and grants a steel and raises the oxygen by 1. Do I calculate cards such as these as if they would be used in every remaining generation? That's probably what I'll do, I just haven't decided yet.
#
# Finally there is a separate group of 23 cards that I don't know how to handle. An example would be Advanced Alloys, which increases the value of steel and titanium by one credit each. I'll probably have to have a separate function for each of those. Hopefully I'll be able to even figure out how to put numbers to each of them.
#
# Before I start writing the probably very long function to determine the value of most of the cards, I will try a few card-specific functions just to get some practice and ideas about how to write the big one.

# %%
# Food Factory test
def food_factory(generation, player_count):
    income, vp, TR, last_gen = initialize(generation, player_count)
    
    value = 0
    value -= 12 #card cost
    value -= round(plant*(income+1))
    value += round(4*income)
    value += vp
    display(f'The value of Food Factory in gen {str(generation)} with {str(player_count)} players is {str(round(value))} credits')
food_factory(1, 2)
# Out:
# 'The value of Food Factory in gen 1 with 2 players is 2 credits'

# %%
# define special case cards to be left out of the main function
special_cases = ['Adaptation Technology', 'Advanced Alloys', 'Anti-Gravity Technology', 'Ants', 
                 'Arctic Algae', 'Business Network', 'Capital', 'CEO’s Favorite Project', 
                 'Commercial District', 'Decomposers', 'Earth Catapult', 'Earth Office', 
                 'Ecological Zone', 
                 'Ganymede Colony', 'GHG Producing Bacteria', 'Herbivores', 'Immigrant City', 
                 'Immigration Shuttles', 
                 'Indentured Workers', 'Insulation', 'Inventor’s Guild', 'Io Mining Industries', 
                 'Land Claim', 
                 'Lava Flows', 'Mars University', 'Martian Rails', 'Mass Converter', 'Media Group', 
                 'Mining Area', 'Mining Rights', 'Nitrite Reducing Bacteria', 
                 'Nitrogen-Rich Asteroid', 'Noctis City', 'Olympus Conference', 'Optimal Aerobraking', 
                 'Pets', 'Phobos Space Haven', 'Power Infrastructure',
                 'Predators', 'Protected Habitat', 'Quantum Extractor', 'Regolith Eaters', 
                 'Research Outpost', 
                 'Robotic Workforce', 'Rover Construction', 'Search for Life', 'Shuttles', 
                 'Space Station', 'Special Design', 
                 'Standard Technology', 'Viral Enhancers', 'Water Import from Europa']

#print(len(special_cases))
base_cases = base_cards[~base_cards.Title.isin(special_cases)].copy().reset_index(drop=True)
#print(len(base_cases) + len(special_cases))

# %%
# main value calculation function
def is_null(x):
    return x is None or (isinstance(x, float) and math.isnan(x))


def compute_additional_cost_value(add_cost, generation, player_count):
    if is_null(add_cost):
        return 0
    value = 0
    for idx, ele in enumerate(add_cost.split(',')):
        add_cost_list = ele.strip().split(' ')
        value -= vars_scan(add_cost_list, generation, player_count)
    return value


def compute_victory_points_value(victory, vp):
    if is_null(victory) or not victory.isdigit():
        return 0
    return int(victory) * vp


def compute_immediate_benefit_value(i_benefit, generation, player_count):
    if is_null(i_benefit):
        return 0

    value = 0

    for idx, ele in enumerate(i_benefit.split(',')):
        i_benefit_list = ele.strip().split(' ')

        # for benefits dependent on the amount of another variable
        if 'per' in i_benefit_list:
            value += pers(i_benefit_list, generation, player_count)

        # for benefits with a choice; the larger of the two values is taken
        elif 'or' in i_benefit_list:
            value += ors((' ').join(i_benefit_list), generation, player_count)

        # for ocean and greenery tiles played on the opposite site
        elif 'land' in i_benefit_list and 'ocean' in i_benefit_list:
            value += ocean + tile_land - tile_ocean
        elif 'ocean' in i_benefit_list and 'greenery' in i_benefit_list:
            value += greenery + tile_ocean - tile_land

        # for special tiles
        elif 'special' in i_benefit_list:
            if 'ocean' in i_benefit_list:
                value += tile_ocean
            else:
                value += tile_land

         # for simple added values
        else:
            value += vars_scan(i_benefit_list, generation, player_count)

    return value


def compute_active_cost_benefit_value(a_cost, a_benefit, victory, generation, last_gen, player_count):
    if is_null(a_cost) or is_null(a_benefit):
        # Note: If one is null then the other must also be null
        return 0

    value = 0
    current_gen = generation

    while current_gen <= last_gen:
        # Cost
        cost = 0
        act_cost_list = a_cost.split(' ')
        if 'or' in a_cost:
            cost = ors(a_cost, current_gen, player_count, cost=True)
        else:
            is_variable_benefit = any(
                x for x in a_benefit.split(' ') if x in vars_dict_variable
            )
            if not is_variable_benefit or (is_variable_benefit and current_gen < last_gen):
                cost = vars_scan(act_cost_list, current_gen, player_count)

        # Benefit
        benefit = 0
        for benefit_list in a_benefit.split(','):
            benefit_list_split = benefit_list.strip().split(' ')
            if 'or' in benefit_list:
                benefit += ors(benefit_list, current_gen, player_count)
            elif 'on card' in benefit_list:
                number = (int(victory[0]) / int(victory[6])) * int(benefit_list[0])
                current_vp = credits_per_vp(current_gen, player_count)
                benefit += number * current_vp
            else:
                variable_eles = set(vars_dict_variable) & {'CREDIT', 'PLANT'}
                is_variable_benefit = any(x for x in benefit_list_split if x in variable_eles)
                if not is_variable_benefit or (is_variable_benefit and current_gen < last_gen):
                    # ensures increased production on the final turn isn't converted into points
                    benefit += vars_scan(benefit_list_split, current_gen, player_count)

        if cost < benefit:
            value += benefit - cost

        current_gen += 1

    return value


def compute_removal_value(removed, generation, player_count):
    if is_null(removed):
        return 0
    
    value = 0
    
    if 'or' in removed:
        value += ors(removed, generation, player_count)
    else:
        value += vars_scan(removed.split(' '), generation, player_count)
    return value


def compute_passive_benefit_value(p_benefit, generation):
    if is_null(p_benefit):
        return 0
    value = 0
    p_benefit_list = p_benefit.split(' ')
    cards_to_play = sum(ave_cards_played[(generation-1):last_gen])
    if not 'tag' in p_benefit_list:
        value = (cards_to_play - 1) * int(p_benefit_list[2])
    elif 'tag' in p_benefit_list:
        for idx, ele in enumerate(p_benefit_list):
            if ele in tags_played_dict:
                value = 4 * (last_gen - generation + 1) * tags_played_dict[ele] * int(p_benefit_list[idx+3])
    return value


def base_value(func):
    def wrapper(database, generation, player_count):
        def compute_value(row):
            income, vp, TR, last_gen = initialize(generation, player_count)
            
            # Primary Cost
            value = -row.at['Primary_Cost']

            # Additional Cost
            add_cost = row.at['Additional_Cost']
            value += compute_additional_cost_value(add_cost, generation, player_count)

            # Victory Points
            victory = row.at['Victory_Points']
            value += compute_victory_points_value(victory, vp)

            # Immediate Benefit
            i_benefit = row.at['Immediate_Benefit']
            value += compute_immediate_benefit_value(i_benefit, generation, player_count)
            
            # Passive Benefit
            p_benefit = row.at['Passive_Benefit']

            # Active Cost/Benefit
            a_cost = row.at['Active_Cost']
            a_benefit = row.at['Active_Benefit']
            value += compute_active_cost_benefit_value(a_cost, a_benefit, victory, generation, last_gen, player_count)

            # Removed from Opponent
            removed = row.at['Removed_from_Opponent']
            value += compute_removal_value(removed, generation, player_count)

            # Special Cases
            value += func(database, generation, player_count, row, last_gen)
            
            return round(value)
    
        new_database = database
        new_database['Value'] = database.apply(compute_value, axis=1)
        new_database['Generation'] = generation
        new_database['Players'] = player_count
            
        return new_database
    return wrapper

# %%
### DEBUGGER
# main value calculation function
def is_null(x):
    return x is None or (isinstance(x, float) and math.isnan(x))

def compute_primary_cost_value(p_cost):
    value = 0
    value += p_cost
    print('Primary Cost = ', p_cost)
    return value

def compute_additional_cost_value(add_cost, generation, player_count):
    if is_null(add_cost):
        return 0
    value = 0
    for idx, ele in enumerate(add_cost.split(',')):
        add_cost_list = ele.strip().split(' ')
        value -= vars_scan(add_cost_list, generation, player_count)
    print('Additional Cost = ', value)
    return value


def compute_victory_points_value(victory, vp):
    if is_null(victory) or len(victory) > 3:
        return 0
    print('Victory Points = ', int(victory) * vp)
    return int(victory) * vp


def compute_immediate_benefit_value(i_benefit, generation, player_count):
    if is_null(i_benefit):
        return 0

    value = 0

    for idx, ele in enumerate(i_benefit.split(',')):
        i_benefit_list = ele.strip().split(' ')

        # for benefits dependent on the amount of another variable
        if 'per' in i_benefit_list:
            value += pers(i_benefit_list, generation, player_count)

        # for benefits with a choice; the larger of the two values is taken
        elif 'or' in i_benefit_list:
            value += ors((' ').join(i_benefit_list), generation, player_count)

        # for ocean and greenery tiles played on the opposite site
        elif 'land' in i_benefit_list and 'ocean' in i_benefit_list:
            value += ocean + tile_land - tile_ocean
        elif 'ocean' in i_benefit_list and 'greenery' in i_benefit_list:
            value += greenery + tile_ocean - tile_land

        # for special tiles
        elif 'special' in i_benefit_list:
            if 'ocean' in i_benefit_list:
                value += tile_ocean
            else:
                value += tile_land

         # for simple added values
        else:
            value += vars_scan(i_benefit_list, generation, player_count)
    print('Immediate Benefit = ', value)
    return value


def compute_active_cost_benefit_value(a_cost, a_benefit, victory, generation, last_gen, player_count):
    if is_null(a_cost) and is_null(a_benefit):
        return 0

    value = 0
    current_gen = generation

    while current_gen <= last_gen:
        # Cost
        cost = 0
        if is_null(a_cost):
            pass
        else:
            act_cost_list = a_cost.split(' ')
            if 'or' in a_cost:
                cost = ors(a_cost, current_gen, player_count, cost=True)
            else:
                is_variable_benefit = any(
                    x for x in a_benefit.split(' ') if x in vars_dict_variable
                )
                if not is_variable_benefit or (is_variable_benefit and current_gen < last_gen):
                    cost = vars_scan(act_cost_list, current_gen, player_count)

        # Benefit
        benefit = 0
        for benefit_list in a_benefit.split(','):
            benefit_list_split = benefit_list.strip().split(' ')
            if 'or' in benefit_list:
                benefit += ors(benefit_list, current_gen, player_count)
            elif 'on card' in benefit_list:
                number = (int(victory[0]) / int(victory[6])) * int(benefit_list[0])
                current_vp = credits_per_vp(current_gen, player_count)
                benefit += number * current_vp
            else:
                variable_eles = set(vars_dict_variable) & {'CREDIT', 'PLANT'}
                is_variable_benefit = any(x for x in benefit_list_split if x in variable_eles)
                if not is_variable_benefit or (is_variable_benefit and current_gen < last_gen):
                    # ensures increased production on the final turn isn't converted into points
                    benefit += vars_scan(benefit_list_split, current_gen, player_count)

        if cost < benefit:
            value += benefit - cost

        current_gen += 1
    print('Active Cost/Benefit = ', value)
    return value


def compute_removal_value(removed, generation, player_count):
    if is_null(removed):
        return 0
    
    value = 0
    
    if 'or' in removed:
        value += ors(removed, generation, player_count)
    else:
        value += vars_scan(removed.split(' '), generation, player_count)
    print('Removal from Opponents = ', value)
    return value


#def compute_passive_benefit_value(p_benefit, generation):
#    if is_null(p_benefit):
#        return 0
#    value = 0
#    p_benefit_list = p_benefit.split(' ')
#    cards_to_play = sum(ave_cards_played[(generation-1):last_gen])
#    if not 'tag' in p_benefit_list:
#        value = (cards_to_play - 1) * int(p_benefit_list[2])
#    elif 'tag' in p_benefit_list:
#        for idx, ele in enumerate(p_benefit_list):
#            if ele in tags_played_dict:
#                value = 4 * (last_gen - generation + 1) * tags_played_dict[ele] * int(p_benefit_list[idx+3])
#    return value


def base_value(func):
    def wrapper(database, generation, player_count):
        def compute_value(row):
            income, vp, TR, last_gen = initialize(generation, player_count)
            
            # Primary Cost
            p_cost = -row.at['Primary_Cost']
            value = compute_primary_cost_value(p_cost)

            # Additional Cost
            add_cost = row.at['Additional_Cost']
            value += compute_additional_cost_value(add_cost, generation, player_count)

            # Victory Points
            victory = row.at['Victory_Points']
            value += compute_victory_points_value(victory, vp)

            # Immediate Benefit
            i_benefit = row.at['Immediate_Benefit']
            value += compute_immediate_benefit_value(i_benefit, generation, player_count)
            
            # Passive Benefit
            p_benefit = row.at['Passive_Benefit']

            # Active Cost/Benefit
            a_cost = row.at['Active_Cost']
            print('active cost = ', row.at['Active_Cost'])
            a_benefit = row.at['Active_Benefit']
            value += compute_active_cost_benefit_value(a_cost, a_benefit, victory, generation, last_gen, player_count)

            # Removed from Opponent
            removed = row.at['Removed_from_Opponent']
            value += compute_removal_value(removed, generation, player_count)

            # Special Cases
            value += func(database, generation, player_count, row, last_gen)
            
            return round(value)
    
        new_database = database
        new_database['Value'] = database.apply(compute_value, axis=1)
        new_database['Generation'] = generation
        new_database['Players'] = player_count
            
        return new_database
    return wrapper

# %%
@base_value
def base_case_tester(database, generation, player_count, *args):
    return 0
    
base_case_tester(base_cases, 11, 2)
# Out:
# Primary Cost =  -10
# Immediate Benefit =  9
# active cost =  nan
# Primary Cost =  -9
# Immediate Benefit =  8.625
# active cost =  nan
# Primary Cost =  -11
# Victory Points =  44.12309757837058
# active cost =  nan
# Primary Cost =  -26
# Immediate Benefit =  30.542524618817595
# active cost =  nan
# Primary Cost =  -21
# Additional Cost =  -6
# Victory Points =  14.707699192790194
# active cost =  nan
# Active Cost/Benefit =  24
# Primary Cost =  -10
# Immediate Benefit =  20.125
# active cost =  nan
# Primary Cost =  -18
# active cost =  8 credit (steel may be spent)
# Active Cost/Benefit =  30
# Primary Cost =  -6
# Immediate Benefit =  8.625
# active cost =  nan
# Primary Cost =  -15
# Victory Points =  14.707699192790194
# Immediate Benefit =  16.4453125
# active cost =  nan
# Primary Cost =  -12
# Immediate Benefit =  12
# active cost =  nan
# Primary Cost =  -14
# Immediate Benefit =  20
# active cost =  nan
# Removal from Opponents =  8.625
# Primary Cost =  -30
# Victory Points =  29.41539838558039
# Immediate Benefit =  12
# active cost =  nan
# Primary Cost =  -13
# Victory Points =  14.707699192790194
# Immediate Benefit =  6
# active cost =  nan
# Removal from Opponents =  6
# Primary Cost =  -32
# Victory Points =  14.707699192790194
# Immediate Benefit =  28.5
# active cost =  nan
# Primary Cost =  -27
# Immediate Benefit =  40
# active cost =  nan
# Removal from Opponents =  11.5
# Primary Cost =  -4
# Victory Points =  -14.707699192790194
# Immediate Benefit =  12
# active cost =  nan
# Removal from Opponents =  8.625
# Primary Cost =  -10
# active cost =  nan
# Active Cost/Benefit =  47.2492884056998
# Removal from Opponents =  17.25
# Primary Cost =  -15
# Additional Cost =  -6
# Immediate Benefit =  28.5
# active cost =  nan
# Primary Cost =  -11
# Victory Points =  29.41539838558039
# active cost =  nan
# Primary Cost =  -7
# Victory Points =  -29.41539838558039
# Immediate Benefit =  33.41539838558039
# active cost =  nan
# Primary Cost =  -6
# Additional Cost =  -6
# Immediate Benefit =  8
# active cost =  nan
# Primary Cost =  -10
# Immediate Benefit =  23.0
# active cost =  nan
# Primary Cost =  -7
# Immediate Benefit =  8
# active cost =  nan
# Primary Cost =  -24
# Victory Points =  29.41539838558039
# Immediate Benefit =  9
# active cost =  nan
# Primary Cost =  -6
# Additional Cost =  -6
# Immediate Benefit =  10.5
# active cost =  nan
# Primary Cost =  -3
# active cost =  8 heat
# Active Cost/Benefit =  8.249288405699797
# Primary Cost =  -8
# Immediate Benefit =  9.375
# active cost =  nan
# Primary Cost =  -11
# Additional Cost =  -3
# Immediate Benefit =  17.25
# active cost =  nan
# Removal from Opponents =  3.5
# Primary Cost =  -8
# Victory Points =  29.41539838558039
# active cost =  nan
# Primary Cost =  -21
# Immediate Benefit =  32
# active cost =  nan
# Removal from Opponents =  8.625
# Primary Cost =  -15
# Immediate Benefit =  22
# active cost =  nan
# Primary Cost =  -11
# Additional Cost =  -6
# Victory Points =  -29.41539838558039
# Immediate Benefit =  31
# active cost =  nan
# Primary Cost =  -16
# Additional Cost =  -6
# Immediate Benefit =  31
# active cost =  nan
# Primary Cost =  -13
# Immediate Benefit =  20
# active cost =  nan
# Primary Cost =  -31
# Immediate Benefit =  50
# active cost =  nan
# Removal from Opponents =  23.0
# Primary Cost =  -16
# Immediate Benefit =  17.25
# active cost =  nan
# Primary Cost =  -11
# active cost =  1 energy
# Active Cost/Benefit =  3
# Primary Cost =  -24
# Additional Cost =  -6
# Victory Points =  14.707699192790194
# Immediate Benefit =  39.625
# active cost =  nan
# Primary Cost =  -2
# Victory Points =  14.707699192790194
# active cost =  nan
# Primary Cost =  -17
# Additional Cost =  -6
# Victory Points =  14.707699192790194
# active cost =  1 plant or 1 steel
# Active Cost/Benefit =  15
# Primary Cost =  -15
# Immediate Benefit =  55.846153846153854
# active cost =  nan
# Primary Cost =  -3
# Victory Points =  -14.707699192790194
# Immediate Benefit =  6
# active cost =  nan
# Removal from Opponents =  6
# Primary Cost =  -16
# Victory Points =  14.707699192790194
# Immediate Benefit =  25.655774394592644
# active cost =  nan
# Primary Cost =  -11
# active cost =  1 ENERGY
# Active Cost/Benefit =  41.2492884056998
# Primary Cost =  -13
# active cost =  nan
# Active Cost/Benefit =  35.395497302691574
# Primary Cost =  -16
# Victory Points =  29.41539838558039
# Immediate Benefit =  29.0
# active cost =  nan
# Primary Cost =  -9
# active cost =  nan
# Active Cost/Benefit =  47.2492884056998
# Removal from Opponents =  8.625
# Primary Cost =  -7
# Victory Points =  -14.707699192790194
# Immediate Benefit =  18
# active cost =  nan
# Removal from Opponents =  4
# Primary Cost =  -12
# Additional Cost =  -8.625
# Victory Points =  14.707699192790194
# Immediate Benefit =  12
# active cost =  nan
# Primary Cost =  -6
# Additional Cost =  -6
# Immediate Benefit =  9
# active cost =  nan
# Primary Cost =  -1
# Additional Cost =  -3
# Immediate Benefit =  6
# active cost =  nan
# Primary Cost =  -14
# Immediate Benefit =  18
# active cost =  nan
# Primary Cost =  -12
# Victory Points =  29.41539838558039
# Immediate Benefit =  6
# active cost =  nan
# Primary Cost =  -11
# Immediate Benefit =  12
# active cost =  nan
# Primary Cost =  -11
# Additional Cost =  -6
# Immediate Benefit =  14.0
# active cost =  nan
# Primary Cost =  -36
# Immediate Benefit =  64
# active cost =  nan
# Removal from Opponents =  17.25
# Primary Cost =  -17
# Immediate Benefit =  18
# active cost =  nan
# Primary Cost =  -11
# Immediate Benefit =  17.25
# active cost =  nan
# Primary Cost =  -12
# Victory Points =  14.707699192790194
# Immediate Benefit =  12
# active cost =  nan
# Primary Cost =  -6
# Immediate Benefit =  4
# active cost =  nan
# Removal from Opponents =  4
# Primary Cost =  -6
# Immediate Benefit =  26.759615384615387
# active cost =  nan
# Primary Cost =  -3
# Additional Cost =  -6
# Victory Points =  -14.707699192790194
# Immediate Benefit =  6
# active cost =  nan
# Removal from Opponents =  6
# Primary Cost =  -6
# Victory Points =  -14.707699192790194
# Immediate Benefit =  6
# active cost =  nan
# Removal from Opponents =  7.0
# Primary Cost =  -6
# Immediate Benefit =  11.5
# active cost =  nan
# Primary Cost =  -1
# Immediate Benefit =  4
# active cost =  nan
# Removal from Opponents =  4
# Primary Cost =  -23
# Immediate Benefit =  36
# active cost =  nan
# Primary Cost =  -5
# Immediate Benefit =  18
# active cost =  nan
# Primary Cost =  -9
# Immediate Benefit =  7.0
# active cost =  nan
# Primary Cost =  -7
# Immediate Benefit =  8.75
# active cost =  nan
# Primary Cost =  -16
# Immediate Benefit =  40.06154878918529
# active cost =  nan
# Primary Cost =  -23
# Immediate Benefit =  67.39553491020186
# active cost =  nan
# Primary Cost =  -4
# Immediate Benefit =  2.2473958333333335
# active cost =  7 credit
# Active Cost/Benefit =  0
# Primary Cost =  -12
# Immediate Benefit =  10
# active cost =  nan
# Primary Cost =  -9
# Immediate Benefit =  43.53966346153847
# active cost =  nan
# Primary Cost =  -24
# Victory Points =  58.83079677116078
# active cost =  nan
# Primary Cost =  -2
# Immediate Benefit =  4
# active cost =  nan
# Primary Cost =  -3
# Additional Cost =  -3
# Immediate Benefit =  10
# active cost =  nan
# Primary Cost =  -11
# active cost =  4 energy
# Active Cost/Benefit =  20.249288405699797
# Primary Cost =  -17
# Victory Points =  14.707699192790194
# Immediate Benefit =  37.625
# active cost =  nan
# Primary Cost =  -9
# Victory Points =  14.707699192790194
# Immediate Benefit =  4
# active cost =  nan
# Primary Cost =  -18
# Victory Points =  29.41539838558039
# Immediate Benefit =  36
# active cost =  nan
# Primary Cost =  -36
# Victory Points =  29.41539838558039
# Immediate Benefit =  70.12309757837058
# active cost =  nan
# Primary Cost =  -7
# Immediate Benefit =  8.625
# active cost =  nan
# Primary Cost =  -8
# Victory Points =  14.707699192790194
# Immediate Benefit =  9
# active cost =  nan
# Primary Cost =  -13
# Additional Cost =  -8.625
# Immediate Benefit =  6
# active cost =  nan
# Active Cost/Benefit =  47.2492884056998
# Primary Cost =  -1
# Additional Cost =  -8.75
# Immediate Benefit =  22.061548789185288
# active cost =  nan
# Primary Cost =  -13
# Additional Cost =  -6
# Immediate Benefit =  19.0
# active cost =  nan
# Primary Cost =  -5
# Additional Cost =  -12
# Immediate Benefit =  25.332699192790194
# active cost =  nan
# Primary Cost =  -20
# Additional Cost =  -24
# Immediate Benefit =  67.37309757837059
# active cost =  nan
# Primary Cost =  -12
# Victory Points =  14.707699192790194
# Immediate Benefit =  24.5546875
# active cost =  nan
# Primary Cost =  -8
# Immediate Benefit =  17.78846153846154
# active cost =  nan
# Primary Cost =  -13
# Victory Points =  14.707699192790194
# Immediate Benefit =  24.15865384615385
# active cost =  nan
# Primary Cost =  -28
# Victory Points =  29.41539838558039
# Immediate Benefit =  24.25
# active cost =  nan
# Primary Cost =  -3
# Immediate Benefit =  3.5
# active cost =  nan
# Primary Cost =  -4
# Immediate Benefit =  4
# active cost =  nan
# Primary Cost =  -5
# Immediate Benefit =  10
# active cost =  nan
# Primary Cost =  -12
# Immediate Benefit =  20.707699192790194
# active cost =  nan
# Removal from Opponents =  5.75
# Primary Cost =  -12
# Victory Points =  14.707699192790194
# Immediate Benefit =  9.375
# active cost =  nan
# Primary Cost =  -20
# Immediate Benefit =  17.802083333333332
# active cost =  nan
# Primary Cost =  -4
# Additional Cost =  -2.875
# Immediate Benefit =  8.625
# active cost =  nan
# Primary Cost =  -9
# Victory Points =  14.707699192790194
# Immediate Benefit =  5.247395833333334
# active cost =  nan
# Primary Cost =  -8
# Additional Cost =  -5.75
# Immediate Benefit =  17.25
# active cost =  nan
# Primary Cost =  -10
# Victory Points =  14.707699192790194
# Immediate Benefit =  8.75
# active cost =  nan
# Primary Cost =  -10
# Additional Cost =  -6
# Immediate Benefit =  18
# active cost =  nan
# Primary Cost =  -10
# Victory Points =  -29.41539838558039
# Immediate Benefit =  30.247395833333332
# active cost =  nan
# Primary Cost =  -23
# Additional Cost =  -6
# Victory Points =  14.707699192790194
# Immediate Benefit =  39.75
# active cost =  nan
# Primary Cost =  -13
# active cost =  4 energy
# Active Cost/Benefit =  23.249288405699797
# Primary Cost =  -8
# Immediate Benefit =  18
# active cost =  nan
# Primary Cost =  -7
# Additional Cost =  -3
# Immediate Benefit =  12
# active cost =  nan
# Primary Cost =  -12
# active cost =  6 energy
# Active Cost/Benefit =  40.4985768113996
# Primary Cost =  -15
# Immediate Benefit =  23
# active cost =  nan
# Primary Cost =  -18
# Immediate Benefit =  38.94230769230769
# active cost =  nan
# Primary Cost =  -4
# Immediate Benefit =  6
# active cost =  nan
# Primary Cost =  -5
# Immediate Benefit =  6
# active cost =  nan
# Removal from Opponents =  6
# Primary Cost =  -23
# Immediate Benefit =  30.5546875
# active cost =  nan
# Primary Cost =  -8
# Additional Cost =  -6
# Immediate Benefit =  33.41539838558039
# active cost =  nan
# Primary Cost =  -6
# Victory Points =  14.707699192790194
# Immediate Benefit =  3
# active cost =  nan
# Primary Cost =  -14
# Immediate Benefit =  33.41539838558039
# active cost =  nan
# Primary Cost =  -11
# Victory Points =  14.707699192790194
# Immediate Benefit =  8
# active cost =  nan
# Primary Cost =  -11
# Immediate Benefit =  2.2473958333333335
# active cost =  2 credit
# Active Cost/Benefit =  6
# Primary Cost =  -1
# active cost =  nan
# Removal from Opponents =  9
# Primary Cost =  -10
# Immediate Benefit =  18.028846153846153
# active cost =  nan
# Primary Cost =  -12
# active cost =  1 titanium
# Active Cost/Benefit =  38.2492884056998
# Primary Cost =  -6
# active cost =  nan
# Active Cost/Benefit =  23.6246442028499
# Removal from Opponents =  8.625
# Primary Cost =  -9
# Additional Cost =  -6
# Victory Points =  14.707699192790194
# Immediate Benefit =  8.625
# active cost =  nan
# Primary Cost =  -11
# Victory Points =  14.707699192790194
# Immediate Benefit =  6
# active cost =  nan
# Primary Cost =  -11
# Immediate Benefit =  12
# active cost =  nan
# Primary Cost =  -35
# Immediate Benefit =  24.5
# active cost =  nan
# Primary Cost =  -27
# Victory Points =  29.41539838558039
# Immediate Benefit =  6
# active cost =  1 steel
# Active Cost/Benefit =  9
# Primary Cost =  -3
# active cost =  7 credit
# Active Cost/Benefit =  0
# Primary Cost =  -6
# Immediate Benefit =  6
# active cost =  nan
# Primary Cost =  -15
# active cost =  4 energy
# Active Cost/Benefit =  26.249288405699797
# Primary Cost =  -25
# Additional Cost =  -12
# Immediate Benefit =  47.41539838558039
# active cost =  nan
# Primary Cost =  -11
# Immediate Benefit =  18
# active cost =  nan
# Primary Cost =  -4
# active cost =  nan
# Active Cost/Benefit =  17.697748651345787
# Primary Cost =  -4
# active cost =  nan
# Active Cost/Benefit =  11.81232210142495
# Primary Cost =  -5
# Immediate Benefit =  8
# active cost =  nan
# Primary Cost =  -18
# Victory Points =  14.707699192790194
# Immediate Benefit =  18
# active cost =  nan
# Primary Cost =  -33
# Victory Points =  29.41539838558039
# Immediate Benefit =  48.19528613304864
# active cost =  nan
# Primary Cost =  -7
# Immediate Benefit =  6
# active cost =  nan
# Primary Cost =  -12
# Immediate Benefit =  18.028846153846153
# active cost =  nan
# Primary Cost =  -23
# Immediate Benefit =  40.457699192790194
# active cost =  nan
# Primary Cost =  -6
# Victory Points =  14.707699192790194
# active cost =  nan
# Primary Cost =  -13
# Victory Points =  14.707699192790194
# Immediate Benefit =  28.75
# active cost =  nan
# Primary Cost =  -13
# Additional Cost =  -7.0
# Victory Points =  29.41539838558039
# Immediate Benefit =  9
# active cost =  nan
# Primary Cost =  -16
# Victory Points =  29.41539838558039
# Immediate Benefit =  17.5
# active cost =  nan
# Primary Cost =  -18
# Additional Cost =  -12
# Immediate Benefit =  30
# active cost =  nan
# Primary Cost =  -6
# active cost =  10 credit
# Active Cost/Benefit =  0
# Primary Cost =  -10
# Additional Cost =  -6
# Immediate Benefit =  28
# active cost =  nan
# Primary Cost =  -15
# Victory Points =  14.707699192790194
# Immediate Benefit =  6
# active cost =  nan
# Primary Cost =  -1
# active cost =  nan
# Removal from Opponents =  22.061548789185288
# Primary Cost =  -12
# active cost =  3 energy
# Active Cost/Benefit =  23.249288405699797
# Primary Cost =  -8
# Victory Points =  14.707699192790194
# Immediate Benefit =  6
# active cost =  nan
# Primary Cost =  -6
# Victory Points =  14.707699192790194
# Immediate Benefit =  6
# active cost =  nan
# Primary Cost =  -8
# Immediate Benefit =  15.549879807692307
# active cost =  nan
# Primary Cost =  -13
# Victory Points =  14.707699192790194
# Immediate Benefit =  27.923076923076927
# active cost =  nan
#                             Title       Game       Type  Primary_Cost  \
# 0                Acquired Company  corporate  automated            10
# 1                  Adapted Lichen       base  automated             9
# 2             Advanced Ecosystems       base  automated            11
# 3     Aerobraked Ammonia Asteroid       base      event            26
# 4                      AI Central  corporate     active            21
# 5                           Algae       base  automated            10
# 6                 Aquifer Pumping       base     active            18
# 7                  Archaebacteria       base  automated             6
# 8                 Artificial Lake       base  automated            15
# 9       Artificial Photosynthesis       base  automated            12
# 10                       Asteroid       base      event            14
# 11                Asteroid Mining       base  automated            30
# 12     Asteroid Mining Consortium  corporate  automated            13
# 13   Beam from a Thorium Asteroid       base  automated            32
# 14                   Big Asteroid       base      event            27
# 15             Biomass Combustors       base  automated             4
# 16                          Birds       base     active            10
# 17               Black Polar Dust       base  automated            15
# 18              Breathing Filters       base  automated            11
# 19               Bribed Committee  corporate      event             7
# 20            Building Industries  corporate  automated             6
# 21                         Bushes       base  automated            10
# 22              Business Contacts  corporate      event             7
# 23           Callisto Penal Mines  corporate  automated            24
# 24           Carbonate Processing       base  automated             6
# 25             Caretaker Contract  corporate     active             3
# 26                         Cartel  corporate  automated             8
# 27                  Cloud Seeding       base  automated            11
# 28        Colonizer Training Camp       base  automated             8
# 29                          Comet       base      event            21
# 30             Convoy From Europa       base      event            15
# 31           Corporate Stronghold  corporate  automated            11
# 32                    Cupola City       base  automated            16
# 33              Deep Well Heating       base  automated            13
# 34                    Deimos Down       base      event            31
# 35        Designed Microorganisms       base  automated            16
# 36             Development Center  corporate     active            11
# 37                   Domed Crater       base  automated            24
# 38                     Dust Seals       base  automated             2
# 39               Electro Catapult  corporate     active            17
# 40                  Energy Saving       base  automated            15
# 41                 Energy Tapping  corporate  automated             3
# 42       Eos Chasma National Park       base  automated            16
# 43          Equatorial Magnetizer       base     active            11
# 44            Extreme Cold Fungus       base     active            13
# 45                        Farming       base  automated            16
# 46                           Fish       base     active             9
# 47                       Flooding       base      event             7
# 48                   Food Factory       base  automated            12
# 49                   Fuel Factory  corporate  automated             6
# 50              Fueled Generators       base  automated             1
# 51                   Fusion Power       base  automated            14
# 52                    Gene Repair  corporate  automated            12
# 53               Geothermal Power       base  automated            11
# 54                  GHG Factories       base  automated            11
# 55             Giant Ice Asteroid       base      event            36
# 56             Giant Space Mirror       base  automated            17
# 57                          Grass       base  automated            11
# 58                      Great Dam       base  automated            12
# 59    Great Escarpment Consortium  corporate  automated             6
# 60                    Greenhouses       base  automated             6
# 61                        Hackers  corporate  automated             3
# 62                  Heat Trappers       base  automated             6
# 63                        Heather       base  automated             6
# 64                  Hired Raiders  corporate      event             1
# 65                   Ice Asteroid       base      event            23
# 66                Ice Cap Melting       base      event             5
# 67         Import of Advanced GHG       base      event             9
# 68                   Imported GHG       base      event             7
# 69              Imported Hydrogen       base      event            16
# 70              Imported Nitrogen       base      event            23
# 71              Industrial Center  corporate     active             4
# 72            Industrial Microbes       base  automated            12
# 73                        Insects       base  automated             9
# 74       Interstellar Colony Ship  corporate      event            24
# 75              Invention Contest  corporate      event             2
# 76                Investment Loan  corporate      event             3
# 77                      Ironworks       base     active            11
# 78                   Kelp Farming       base  automated            17
# 79           LaGrange Observatory  corporate  automated             9
# 80                 Lake Marineris       base  automated            18
# 81                   Large Convoy       base      event            36
# 82                         Lichen       base  automated             7
# 83              Lightning Harvest       base  automated             8
# 84                      Livestock       base     active            13
# 85            Local Heat Trapping       base      event             1
# 86                     Lunar Beam       base  automated            13
# 87            Magnetic Field Dome       base  automated             5
# 88       Magnetic Field Generator       base  automated            20
# 89                       Mangrove       base  automated            12
# 90                 Media Archives  corporate  automated             8
# 91                    Medical Lab  corporate  automated            13
# 92             Methane from Titan       base  automated            28
# 93                    Micro-Mills       base  automated             3
# 94                           Mine  corporate  automated             4
# 95                Mineral Deposit  corporate      event             5
# 96              Mining Expedition       base      event            12
# 97                 Miranda Resort  corporate  automated            12
# 98                    Mohole Area       base  automated            20
# 99                           Moss       base  automated             4
# 100              Natural Preserve       base  automated             9
# 101              Nitrophilic Moss       base  automated             8
# 102                Noctis Farming       base  automated            10
# 103                 Nuclear Power       base  automated            10
# 104                  Nuclear Zone       base  automated            10
# 105                     Open City       base  automated            23
# 106                 Ore Processor       base     active            13
# 107         Permafrost Extraction       base      event             8
# 108                Peroxide Power       base  automated             7
# 109               Physics Complex  corporate     active            12
# 110                    Plantation       base  automated            15
# 111                    Power Grid       base  automated            18
# 112                   Power Plant       base  automated             4
# 113       Power Supply Consortium  corporate  automated             5
# 114              Protected Valley       base  automated            23
# 115              Rad-Chem Factory       base  automated             8
# 116                     Rad-Suits  corporate  automated             6
# 117        Release of Inert Gases       base      event            14
# 118                      Research  corporate  automated            11
# 119               Restricted Area  corporate     active            11
# 120                      Sabotage  corporate      event             1
# 121                    Satellites  corporate  automated            10
# 122                Security Fleet  corporate     active            12
# 123                 Small Animals       base     active             6
# 124                  Soil Factory       base  automated             9
# 125                   Solar Power       base  automated            11
# 126              Solar Wind Power       base  automated            11
# 127                       Soletta       base  automated            35
# 128                Space Elevator  corporate     active            27
# 129                 Space Mirrors       base     active             3
# 130                      Sponsors  corporate  automated             6
# 131                    Steelworks       base     active            15
# 132                    Strip Mine       base  automated            25
# 133        Subterranean Reservoir       base      event            11
# 134              Symbiotic Fungus       base     active             4
# 135                   Tardigrades  corporate     active             4
# 136      Technology Demonstration  corporate      event             5
# 137         Tectonic Stress Power       base  automated            18
# 138         Terraforming Ganymede  corporate  automated            33
# 139                 Titanium Mine  corporate  automated             7
# 140                  Toll Station  corporate  automated            12
# 141                Towing a Comet       base      event            23
# 142           Trans-Neptune Probe  corporate  automated             6
# 143                         Trees       base  automated            13
# 144               Tropical Resort  corporate  automated            13
# 145                Tundra Farming       base  automated            16
# 146              Underground City       base  automated            18
# 147        Underground Detonation       base     active             6
# 148                Urbanized Area       base  automated            10
# 149                Vesta Shipyard  corporate  automated            15
# 150                         Virus  corporate      event             1
# 151         Water Splitting Plant       base     active            12
# 152                    Wave Power       base  automated             8
# 153                     Windmills       base  automated             6
# 154                         Worms       base  automated             8
# 155                     Zeppelins       base  automated            13
#
#     Additional_Cost                      Tags  \
# 0               NaN                     earth
# 1               NaN                     plant
# 2               NaN    plant, microbe, animal
# 3               NaN              space, event
# 4          1 ENERGY         science, building
# 5               NaN                     plant
# 6               NaN                  building
# 7               NaN                   microbe
# 8               NaN                  building
# 9               NaN                   science
# 10              NaN              space, event
# 11              NaN             jovian, space
# 12              NaN                    jovian
# 13              NaN      jovian, space, power
# 14              NaN              space, event
# 15              NaN           power, building
# 16              NaN                    animal
# 17         2 CREDIT                       NaN
# 18              NaN                   science
# 19              NaN              earth, event
# 20         1 ENERGY                  building
# 21              NaN                     plant
# 22              NaN              earth, event
# 23              NaN             jovian, space
# 24         1 ENERGY                  building
# 25              NaN                       NaN
# 26              NaN                     earth
# 27         1 CREDIT                       NaN
# 28              NaN          jovian, building
# 29              NaN              space, event
# 30              NaN              space, event
# 31         1 ENERGY            city, building
# 32         1 ENERGY            city, building
# 33              NaN           power, building
# 34              NaN              space, event
# 35              NaN          science, microbe
# 36              NaN         science, building
# 37         1 ENERGY            city, building
# 38              NaN                       NaN
# 39         1 ENERGY                  building
# 40              NaN                     power
# 41              NaN                     power
# 42              NaN           plant, building
# 43              NaN                  building
# 44              NaN                   microbe
# 45              NaN                     plant
# 46              NaN                    animal
# 47              NaN                     event
# 48          1 PLANT                  building
# 49         1 ENERGY                  building
# 50         1 CREDIT           power, building
# 51              NaN  science, power, building
# 52              NaN                   science
# 53              NaN           power, building
# 54         1 ENERGY                  building
# 55              NaN              space, event
# 56              NaN              power, space
# 57              NaN                     plant
# 58              NaN           power, building
# 59              NaN                       NaN
# 60              NaN           plant, building
# 61         1 ENERGY                       NaN
# 62              NaN           power, building
# 63              NaN                     plant
# 64              NaN                     event
# 65              NaN              space, event
# 66              NaN                     event
# 67              NaN       earth, space, event
# 68              NaN       earth, space, event
# 69              NaN       earth, space, event
# 70              NaN       earth, space, event
# 71              NaN                  building
# 72              NaN         microbe, building
# 73              NaN                   microbe
# 74              NaN       earth, space, event
# 75              NaN            science, event
# 76         1 CREDIT              earth, event
# 77              NaN                  building
# 78              NaN                     plant
# 79              NaN            science, space
# 80              NaN                       NaN
# 81              NaN       earth, space, event
# 82              NaN                     plant
# 83              NaN                     power
# 84          1 PLANT                    animal
# 85           5 heat                     event
# 86         2 CREDIT              earth, power
# 87         2 ENERGY                  building
# 88         4 ENERGY                  building
# 89              NaN                     plant
# 90              NaN                     earth
# 91              NaN         science, building
# 92              NaN             jovian, space
# 93              NaN                       NaN
# 94              NaN                  building
# 95              NaN                     event
# 96              NaN                     event
# 97              NaN             jovian, space
# 98              NaN                  building
# 99          1 plant                     plant
# 100             NaN         science, building
# 101         2 plant                     plant
# 102             NaN           plant, building
# 103        2 CREDIT           power, building
# 104             NaN                     earth
# 105        1 ENERGY            city, building
# 106             NaN                  building
# 107             NaN                     event
# 108        1 CREDIT           power, building
# 109             NaN         science, building
# 110             NaN                     plant
# 111             NaN                     power
# 112             NaN           power, building
# 113             NaN                     power
# 114             NaN           plant, building
# 115        1 ENERGY                  building
# 116             NaN                       NaN
# 117             NaN                     event
# 118             NaN                 2 science
# 119             NaN                   science
# 120             NaN                     event
# 121             NaN                     space
# 122             NaN                     space
# 123             NaN                    animal
# 124        1 ENERGY                  building
# 125             NaN           power, building
# 126             NaN     science, space, power
# 127             NaN                     space
# 128             NaN           space, building
# 129             NaN              power, space
# 130             NaN                     earth
# 131             NaN                  building
# 132        2 ENERGY                  building
# 133             NaN                     event
# 134             NaN                   microbe
# 135             NaN                   microbe
# 136             NaN     science, space, event
# 137             NaN           power, building
# 138             NaN             jovian, space
# 139             NaN                  building
# 140             NaN                     space
# 141             NaN              space, event
# 142             NaN            science, space
# 143             NaN                     plant
# 144          2 HEAT                  building
# 145             NaN                     plant
# 146        2 ENERGY            city, building
# 147             NaN                  building
# 148        1 ENERGY            city, building
# 149             NaN             jovian, space
# 150             NaN            microbe, event
# 151             NaN                  building
# 152             NaN                     power
# 153             NaN           power, building
# 154             NaN                   microbe
# 155             NaN                       NaN
#
#                             Prerequisites            Victory_Points  \
# 0                                     NaN                       NaN
# 1                                     NaN                       NaN
# 2    1 plant, 1 microbe, and 1 animal tag                         3
# 3                                     NaN                       NaN
# 4                           3 science tag                         1
# 5                                 5 ocean                       NaN
# 6                                     NaN                       NaN
# 7                               max -18°C                       NaN
# 8                                    -6°C                         1
# 9                                     NaN                       NaN
# 10                                    NaN                       NaN
# 11                                    NaN                         2
# 12                             1 TITANIUM                         1
# 13                           1 jovian tag                         1
# 14                                    NaN                       NaN
# 15                              6% oxygen                        -1
# 16                             13% oxygen    1 per 1 animal on card
# 17                                    NaN                       NaN
# 18                              7% oxygen                         2
# 19                                    NaN                        -2
# 20                                    NaN                       NaN
# 21                                  -10°C                       NaN
# 22                                    NaN                       NaN
# 23                                    NaN                         2
# 24                                    NaN                       NaN
# 25                                    0°C                       NaN
# 26                                    NaN                       NaN
# 27                                3 ocean                       NaN
# 28                          max 5% oxygen                         2
# 29                                    NaN                       NaN
# 30                                    NaN                       NaN
# 31                                    NaN                        -2
# 32                          max 9% oxygen                       NaN
# 33                                    NaN                       NaN
# 34                                    NaN                       NaN
# 35                              max -14°C                       NaN
# 36                                    NaN                       NaN
# 37                          max 7% oxygen                         1
# 38                            max 3 ocean                         1
# 39                          max 8% oxygen                         1
# 40                                    NaN                       NaN
# 41                                    NaN                        -1
# 42                                  -12°C                         1
# 43                                    NaN                       NaN
# 44                              max -10°C                       NaN
# 45                                   +4°C                         2
# 46                                   +2°C    1 per 1 animal on card
# 47                                    NaN                        -1
# 48                                    NaN                         1
# 49                                    NaN                       NaN
# 50                                    NaN                       NaN
# 51                            2 power tag                       NaN
# 52                          3 science tag                         2
# 53                                    NaN                       NaN
# 54                                    NaN                       NaN
# 55                                    NaN                       NaN
# 56                                    NaN                       NaN
# 57                                  -16°C                       NaN
# 58                                4 ocean                         1
# 59                                1 STEEL                       NaN
# 60                                    NaN                       NaN
# 61                                    NaN                        -1
# 62                                    NaN                        -1
# 63                                  -14°C                       NaN
# 64                                    NaN                       NaN
# 65                                    NaN                       NaN
# 66                                   +2°C                       NaN
# 67                                    NaN                       NaN
# 68                                    NaN                       NaN
# 69                                    NaN                       NaN
# 70                                    NaN                       NaN
# 71                                    NaN                       NaN
# 72                                    NaN                       NaN
# 73                              6% oxygen                       NaN
# 74                          5 science tag                         4
# 75                                    NaN                       NaN
# 76                                    NaN                       NaN
# 77                                    NaN                       NaN
# 78                                6 ocean                         1
# 79                                    NaN                         1
# 80                                    0°C                         2
# 81                                    NaN                         2
# 82                                  -24°C                       NaN
# 83                          3 science tag                         1
# 84                              9% oxygen    1 per 1 animal on card
# 85                                    NaN                       NaN
# 86                                    NaN                       NaN
# 87                                    NaN                       NaN
# 88                                    NaN                       NaN
# 89                                   +4°C                         1
# 90                                    NaN                       NaN
# 91                                    NaN                         1
# 92                              2% oxygen                         2
# 93                                    NaN                       NaN
# 94                                    NaN                       NaN
# 95                                    NaN                       NaN
# 96                                    NaN                       NaN
# 97                                    NaN                         1
# 98                                    NaN                       NaN
# 99                                3 ocean                       NaN
# 100                         max 4% oxygen                         1
# 101                               3 ocean                       NaN
# 102                                 -20°C                         1
# 103                                   NaN                       NaN
# 104                                   NaN                        -2
# 105                            12% oxygen                         1
# 106                                   NaN                       NaN
# 107                                  -8°C                       NaN
# 108                                   NaN                       NaN
# 109                                   NaN  2 per 1 resource on card
# 110                         2 science tag                       NaN
# 111                                   NaN                       NaN
# 112                                   NaN                       NaN
# 113                           2 power tag                       NaN
# 114                                   NaN                       NaN
# 115                                   NaN                       NaN
# 116                            any 2 city                         1
# 117                                   NaN                       NaN
# 118                                   NaN                         1
# 119                                   NaN                       NaN
# 120                                   NaN                       NaN
# 121                                   NaN                       NaN
# 122                                   NaN  1 per 1 resource on card
# 123                             6% oxygen    1 per 2 animal on card
# 124                                   NaN                         1
# 125                                   NaN                         1
# 126                                   NaN                       NaN
# 127                                   NaN                       NaN
# 128                                   NaN                         2
# 129                                   NaN                       NaN
# 130                                   NaN                       NaN
# 131                                   NaN                       NaN
# 132                                   NaN                       NaN
# 133                                   NaN                       NaN
# 134                                 -14°C                       NaN
# 135                                   NaN   1 per 4 microbe on card
# 136                                   NaN                       NaN
# 137                         2 science tag                         1
# 138                                   NaN                         2
# 139                                   NaN                       NaN
# 140                                   NaN                       NaN
# 141                                   NaN                       NaN
# 142                                   NaN                         1
# 143                                  -4°C                         1
# 144                                   NaN                         2
# 145                                  -6°C                         2
# 146                                   NaN                       NaN
# 147                                   NaN                       NaN
# 148                                   NaN                       NaN
# 149                                   NaN                         1
# 150                                   NaN                       NaN
# 151                               2 ocean                       NaN
# 152                               3 ocean                         1
# 153                             7% oxygen                         1
# 154                             4% oxygen                       NaN
# 155                             5% oxygen                         1
#
#                                                          Immediate_Benefit  \
# 0                                                                 3 CREDIT
# 1                                                                  1 PLANT
# 2                                                                      NaN
# 3                                 2 microbe on other card, 3 HEAT, 1 PLANT
# 4                                                                      NaN
# 5                                                         1 plant, 2 PLANT
# 6                                                                      NaN
# 7                                                                  1 PLANT
# 8                                                     1 ocean on land site
# 9                                                      1 PLANT or 2 ENERGY
# 10                                                      1 temp, 2 titanium
# 11                                                              2 TITANIUM
# 12                                                              1 TITANIUM
# 13                                                        3 HEAT, 3 ENERGY
# 14                                                      2 temp, 4 titanium
# 15                                                                2 ENERGY
# 16                                                                     NaN
# 17                                                         3 HEAT, 1 ocean
# 18                                                                     NaN
# 19                                                                    2 TR
# 20                                                                 2 STEEL
# 21                                                        2 PLANT, 2 plant
# 22                                          4 draw, then discard 2 of them
# 23                                                                3 CREDIT
# 24                                                                  3 HEAT
# 25                                                                     NaN
# 26                                         1 CREDIT per 1 player earth tag
# 27                                                                 2 PLANT
# 28                                                                     NaN
# 29                                                         1 temp, 1 ocean
# 30                                                         1 ocean, 1 draw
# 31                                                        3 CREDIT, 1 city
# 32                                                        3 CREDIT, 1 city
# 33                                                        1 ENERGY, 1 temp
# 34                                                         3 temp, 4 steel
# 35                                                                 2 PLANT
# 36                                                                     NaN
# 37                                               3 plant, 3 CREDIT, 1 city
# 38                                                                     NaN
# 39                                                                     NaN
# 40                                                     1 ENERGY per 1 city
# 41                                                                1 ENERGY
# 42                               1 animal on other card, 3 plant, 2 CREDIT
# 43                                                                     NaN
# 44                                                                     NaN
# 45                                              2 CREDIT, 2 PLANT, 2 plant
# 46                                                                     NaN
# ...
# 139                                 NaN
# 140                                 NaN
# 141                                 NaN
# 142                                 NaN
# 143                                 NaN
# 144                                 NaN
# 145                                 NaN
# 146                                 NaN
# 147                              2 HEAT
# 148                                 NaN
# 149                                 NaN
# 150                                 NaN
# 151                            1 oxygen
# 152                                 NaN
# 153                                 NaN
# 154                                 NaN
# 155                                 NaN
#
#                                       Removed_from_Opponent  Value  \
# 0                                                       NaN     -1
# 1                                                       NaN      0
# 2                                                       NaN     33
# 3                                                       NaN      5
# 4                                                       NaN     12
# 5                                                       NaN     10
# 6                                                       NaN     12
# 7                                                       NaN      3
# 8                                                       NaN     16
# 9                                                       NaN      0
# 10                                                  3 plant     15
# 11                                                      NaN     11
# 12                                               1 TITANIUM     14
# 13                                                      NaN     11
# 14                                                  4 plant     24
# 15                                                  1 PLANT      2
# 16                                                  2 PLANT     54
# 17                                                      NaN      8
# 18                                                      NaN     18
# 19                                                      NaN     -3
# 20                                                      NaN     -4
# 21                                                      NaN     13
# 22                                                      NaN      1
# 23                                                      NaN     14
# 24                                                      NaN     -2
# 25                                                      NaN      5
# 26                                                      NaN      1
# 27                                                   1 HEAT      7
# 28                                                      NaN     21
# 29                                                  3 plant     20
# 30                                                      NaN      7
# 31                                                      NaN    -15
# 32                                                      NaN      9
# 33                                                      NaN      7
# 34                                                  8 plant     42
# 35                                                      NaN      1
# 36                                                      NaN     -8
# 37                                                      NaN     24
# 38                                                      NaN     13
# 39                                                      NaN      7
# 40                                                      NaN     41
# 41                                                 1 ENERGY     -6
# 42                                                      NaN     24
# 43                                                      NaN     30
# 44                                                      NaN     22
# 45                                                      NaN     42
# 46                                                  1 PLANT     47
# 47   4 credit from owner of a tile adjacent to placed ocean      0
# 48                                                      NaN      6
# 49                                                      NaN     -3
# 50                                                      NaN      2
# 51                                                      NaN      4
# 52                                                      NaN     23
# 53                                                      NaN      1
# 54                                                      NaN     -3
# 55                                                  6 plant     45
# 56                                                      NaN      1
# 57                                                      NaN      6
# 58                                                      NaN     15
# 59                                                  1 STEEL      2
# 60                                                      NaN     21
# 61                                                 2 CREDIT    -12
# 62                                                   2 HEAT     -8
# 63                                                      NaN      6
# 64                                      2 steel or 3 credit      7
# 65                                                      NaN     13
# 66                                                      NaN     13
# 67                                                      NaN     -2
# 68                                                      NaN      2
# 69                                                      NaN     24
# 70                                                      NaN     44
# 71                                                      NaN     -2
# 72                                                      NaN     -2
# 73                                                      NaN     35
# 74                                                      NaN     35
# 75                                                      NaN      2
# 76                                                      NaN      4
# 77                                                      NaN      9
# 78                                                      NaN     35
# 79                                                      NaN     10
# 80                                                      NaN     47
# 81                                                      NaN     64
# 82                                                      NaN      2
# 83                                                      NaN     16
# 84                                                      NaN     32
# 85                                                      NaN     12
# 86                                                      NaN      0
# 87                                                      NaN      8
# 88                                                      NaN     23
# 89                                                      NaN     27
# 90                                                      NaN     10
# 91                                                      NaN     26
# 92                                                      NaN     26
# 93                                                      NaN      0
# 94                                                      NaN      0
# 95                                                      NaN      5
# 96                                                  2 plant     14
# 97                                                      NaN     12
# 98                                                      NaN     -2
# 99                                                      NaN      2
# 100                                                     NaN     11
# 101                                                     NaN      4
# 102                                                     NaN     13
# 103                                                     NaN      2
# 104                                                     NaN     -9
# 105                                                     NaN     25
# 106                                                     NaN     10
# 107                                                     NaN     10
# 108                                                     NaN      2
# 109                                                     NaN     28
# 110                                                     NaN      8
# 111                                                     NaN     21
# 112                                                     NaN      2
# 113                                                1 ENERGY      7
# 114                                                     NaN      8
# 115                                                     NaN     19
# 116                                                     NaN     12
# 117                                                     NaN     19
# 118                                                     NaN     12
# 119                                                     NaN     -3
# 120                       3 titanium or 4 steel or 7 credit      8
# 121                                                     NaN      8
# 122                                                     NaN     26
# 123                                                 1 PLANT     26
# 124                                                     NaN      8
# 125                                                     NaN     10
# 126                                                     NaN      1
# 127                                                     NaN    -10
# 128                                                     NaN     17
# 129                                                     NaN     -3
# 130                                                     NaN      0
# 131                                                     NaN     11
# 132                                                     NaN     10
# 133                                                     NaN      7
# 134                                                     NaN     14
# 135                                                     NaN      8
# 136                                                     NaN      3
# 137                                                     NaN     15
# 138                                                     NaN     45
# 139                                                     NaN     -1
# 140                                                     NaN      6
# 141                                                     NaN     17
# 142                                                     NaN      9
# 143                                                     NaN     30
# 144                                                     NaN     18
# 145                                                     NaN     31
# 146                                                     NaN      0
# 147                                                     NaN     -6
# 148                                                     NaN     12
# 149                                                     NaN      6
# 150                                     2 animal or 5 plant     21
# 151                                                     NaN     11
# 152                                                     NaN     13
# 153                                                     NaN     15
# 154                                                     NaN      8
# 155                                                     NaN     30
#
#      Generation  Players
# 0            11        2
# 1            11        2
# 2            11        2
# 3            11        2
# 4            11        2
# 5            11        2
# 6            11        2
# 7            11        2
# 8            11        2
# 9            11        2
# 10           11        2
# 11           11        2
# 12           11        2
# 13           11        2
# 14           11        2
# 15           11        2
# 16           11        2
# 17           11        2
# 18           11        2
# 19           11        2
# 20           11        2
# 21           11        2
# 22           11        2
# 23           11        2
# 24           11        2
# 25           11        2
# 26           11        2
# 27           11        2
# 28           11        2
# 29           11        2
# 30           11        2
# 31           11        2
# 32           11        2
# 33           11        2
# 34           11        2
# 35           11        2
# 36           11        2
# 37           11        2
# 38           11        2
# 39           11        2
# 40           11        2
# 41           11        2
# 42           11        2
# 43           11        2
# 44           11        2
# 45           11        2
# 46           11        2
# 47           11        2
# 48           11        2
# 49           11        2
# 50           11        2
# 51           11        2
# 52           11        2
# 53           11        2
# 54           11        2
# 55           11        2
# 56           11        2
# 57           11        2
# 58           11        2
# 59           11        2
# 60           11        2
# 61           11        2
# 62           11        2
# 63           11        2
# 64           11        2
# 65           11        2
# 66           11        2
# 67           11        2
# 68           11        2
# 69           11        2
# 70           11        2
# 71           11        2
# 72           11        2
# 73           11        2
# 74           11        2
# 75           11        2
# 76           11        2
# 77           11        2
# 78           11        2
# 79           11        2
# 80           11        2
# 81           11        2
# 82           11        2
# 83           11        2
# 84           11        2
# 85           11        2
# 86           11        2
# 87           11        2
# 88           11        2
# 89           11        2
# 90           11        2
# 91           11        2
# 92           11        2
# 93           11        2
# 94           11        2
# 95           11        2
# 96           11        2
# 97           11        2
# 98           11        2
# 99           11        2
# 100          11        2
# 101          11        2
# 102          11        2
# 103          11        2
# 104          11        2
# 105          11        2
# 106          11        2
# 107          11        2
# 108          11        2
# 109          11        2
# 110          11        2
# 111          11        2
# 112          11        2
# 113          11        2
# 114          11        2
# 115          11        2
# 116          11        2
# 117          11        2
# 118          11        2
# 119          11        2
# 120          11        2
# 121          11        2
# 122          11        2
# 123          11        2
# 124          11        2
# 125          11        2
# 126          11        2
# 127          11        2
# 128          11        2
# 129          11        2
# 130          11        2
# 131          11        2
# 132          11        2
# 133          11        2
# 134          11        2
# 135          11        2
# 136          11        2
# 137          11        2
# 138          11        2
# 139          11        2
# 140          11        2
# 141          11        2
# 142          11        2
# 143          11        2
# 144          11        2
# 145          11        2
# 146          11        2
# 147          11        2
# 148          11        2
# 149          11        2
# 150          11        2
# 151          11        2
# 152          11        2
# 153          11        2
# 154          11        2
# 155          11        2

# %%
# Single card tester
special_case_db = base_cards[base_cards.Title.isin(special_cases)].copy().reset_index(drop=True)

biomass_combustors = base_cases[base_cases.Title == 'Biomass Combustors'].copy()
display(biomass_combustors)

print('income, vp, TR, last gen = ', initialize(11, 2))
print('land tile = ', tile_land)
print('ocean tile = ', tile_ocean)
print('animal = ', animal_val(11, 2))
print('microbe = ', microbe_val(11, 2))
generation = 11
player_count = 2
vp_list = []
for players in last_gens:
    if str(player_count) in players:
        last_gen = last_gens[players]
for i in range(generation, last_gen + 1):
    vp_list.append(credits_per_vp(i, player_count))
print('rem gen vps = ', vp_list)

print('************')
base_case_tester(biomass_combustors, 11, 2)
# Out:
#                  Title  Game       Type  Primary_Cost Additional_Cost  \
# 15  Biomass Combustors  base  automated             4             NaN
#
#                Tags Prerequisites Victory_Points Immediate_Benefit  \
# 15  power, building     6% oxygen             -1          2 ENERGY
#
#    Passive_Benefit Active_Cost Active_Benefit Removed_from_Opponent  Value  \
# 15             NaN         NaN            NaN               1 PLANT      2
#
#     Generation  Players
# 15          11        2
# income, vp, TR, last gen =  (2, 14.707699192790194, 16.707699192790194, 13)
# land tile =  2.2473958333333335
# ocean tile =  3.8020833333333335
# animal =  11.030774394592644
# microbe =  5.7087623094087965
# rem gen vps =  [14.707699192790194, 15.751437078285592, 16.790152134624012]
# ************
# Primary Cost =  -4
# Victory Points =  -14.707699192790194
# Immediate Benefit =  12
# active cost =  nan
# Removal from Opponents =  8.625
#                  Title  Game       Type  Primary_Cost Additional_Cost  \
# 15  Biomass Combustors  base  automated             4             NaN
#
#                Tags Prerequisites Victory_Points Immediate_Benefit  \
# 15  power, building     6% oxygen             -1          2 ENERGY
#
#    Passive_Benefit Active_Cost Active_Benefit Removed_from_Opponent  Value  \
# 15             NaN         NaN            NaN               1 PLANT      2
#
#     Generation  Players
# 15          11        2

# %% [markdown]
# ## General Notes -
#
# * Ignoring opportunity cost. This is why a card draw is worth only 4. Certain cards will be slightly devalued due to this, such as Business Contacts (where the extra two cards drawn and then discarded are not tallied)
# * Greeneries and Cities. The map point from a greenery is used in calculating the value of victory points, but it is not added to the value of the greenery standard project. Likewise, the potential map value of a city tile is not added to the value of the city standard project. The reasoning for this is that those map points/potential map points have been factored into determining the cost of the standard project.
# * Tile placement bonus. Average added values have been determined for placing a tile on a land area or on an ocean area based on the resource bonuses printed on some of those areas. These bonuses have been factored into the cost of the relevant standard projects.
# * In most cases numbers are rounded only at the point of presenting the final card values.

# %% [markdown]
# #### Project Notes -
# * In the `pers()` function in TM_lib.ipynb, the event portion is focused solely on Media Archives. Only "all events played" is handled. If I add any expansions later on, I will need to update this if any cards rely on the number of events played by the current player only.
# * For concision, I've only distinguished between tags played and tags showing for those tags that have any event versions. If I add any expansions, I'll have to reassess.
# * First generation Birds is impossible but a value is still attached to it. This is probably not a big deal as I'm ignoring prerequisites. Getting first generation Ironworks will yield an oxygen every generation, even though there is a limited amount of oxygen and some of it will get raised by other players. This is a bigger problem I need to think about.
